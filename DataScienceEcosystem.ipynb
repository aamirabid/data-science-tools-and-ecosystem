# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# **Objectives:**
# - List popular languages for Data Science
# - List commonly used Data Science libraries
# - Create tables in markdown
# - Perform basic arithmetic operations using Python
# - Convert minutes into hours using Python code

# %% [markdown]
# Some of the popular languages that Data Scientists use are:
# 1. Python
# 2. R
# 3. SQL
# 4. Julia
# 5. Scala

# %% [markdown]
# Some of the commonly used libraries used by Data Scientists include:
# 1. Pandas
# 2. NumPy
# 3. Matplotlib
# 4. Scikit-learn

# %% [markdown]
# | Data Science Tools |
# |--------------------|
# | Jupyter Notebook   |
# | RStudio            |
# | Apache Zeppelin    |

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python.

# %%
# This is a simple arithmetic expression to multiply then add integers
(3*4) + 5

# %%
# This will convert 200 minutes to hours by dividing by 60
200 / 60

# %% [markdown]
# ## Author
# Mohammad Aamir
# [Linkedin](https://www.linkedin.com/in/mohammadaamirr/)

# %% [markdown]
# ### Notebook Link
# You can access the GitHub notebook here: [GitHub Repository Link](https://github.com/aamirabid/data-science-tools-and-ecosystem)
